# %%
from keras.layers import Input, merge, Dropout, Dense, Flatten, Activation
from keras.layers.convolutional import MaxPooling2D, Convolution2D, AveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.models import Model

from keras import backend as K
from keras.utils.data_utils import get_file

"""
Implementation of Inception Network v4 [Inception Network v4 Paper](http://arxiv.org/pdf/1602.07261v1.pdf) in Keras.
"""

TH_BACKEND_TH_DIM_ORDERING = "https://github.com/titu1994/Inception-v4/releases/download/v1.2/inception_v4_weights_th_dim_ordering_th_kernels.h5"
TH_BACKEND_TF_DIM_ORDERING = "https://github.com/titu1994/Inception-v4/releases/download/v1.2/inception_v4_weights_tf_dim_ordering_th_kernels.h5"
TF_BACKEND_TF_DIM_ORDERING = "https://github.com/titu1994/Inception-v4/releases/download/v1.2/inception_v4_weights_tf_dim_ordering_tf_kernels.h5"
TF_BACKEND_TH_DIM_ORDERING = "https://github.com/titu1994/Inception-v4/releases/download/v1.2/inception_v4_weights_th_dim_ordering_tf_kernels.h5"


def conv_block(x, nb_filter, nb_row, nb_col, border_mode='same', subsample=(1, 1), bias=False):
    if K.image_dim_ordering() == "th":
        channel_axis = 1
    else:
        channel_axis = -1

    x = Convolution2D(nb_filter, nb_row, nb_col, subsample=subsample, border_mode=border_mode, bias=bias)(x)
    x = BatchNormalization(axis=channel_axis)(x)
    x = Activation('relu')(x)
    return x


def inception_stem(input):
    if K.image_dim_ordering() == "th":
        channel_axis = 1
    else:
        channel_axis = -1

    # Input Shape is 299 x 299 x 3 (th) or 3 x 299 x 299 (th)
    x = conv_block(input, 32, 3, 3, subsample=(2, 2), border_mode='valid')
    x = conv_block(x, 32, 3, 3, border_mode='valid')
    x = conv_block(x, 64, 3, 3)

    x1 = MaxPooling2D((3, 3), strides=(2, 2), border_mode='valid')(x)
    x2 = conv_block(x, 96, 3, 3, subsample=(2, 2), border_mode='valid')

    x = merge([x1, x2], mode='concat', concat_axis=channel_axis)

    x1 = conv_block(x, 64, 1, 1)
    x1 = conv_block(x1, 96, 3, 3, border_mode='valid')

    x2 = conv_block(x, 64, 1, 1)
    x2 = conv_block(x2, 64, 1, 7)
    x2 = conv_block(x2, 64, 7, 1)
    x2 = conv_block(x2, 96, 3, 3, border_mode='valid')

    x = merge([x1, x2], mode='concat', concat_axis=channel_axis)

    x1 = conv_block(x, 192, 3, 3, subsample=(2, 2), border_mode='valid')
    x2 = MaxPooling2D((3, 3), strides=(2, 2), border_mode='valid')(x)

    x = merge([x1, x2], mode='concat', concat_axis=channel_axis)
    return x


def inception_A(input):
    if K.image_dim_ordering() == "th":
        channel_axis = 1
    else:
        channel_axis = -1

    a1 = conv_block(input, 96, 1, 1)

    a2 = conv_block(input, 64, 1, 1)
    a2 = conv_block(a2, 96, 3, 3)

    a3 = conv_block(input, 64, 1, 1)
    a3 = conv_block(a3, 96, 3, 3)
    a3 = conv_block(a3, 96, 3, 3)

    a4 = AveragePooling2D((3, 3), strides=(1, 1), border_mode='same')(input)
    a4 = conv_block(a4, 96, 1, 1)

    m = merge([a1, a2, a3, a4], mode='concat', concat_axis=channel_axis)
    return m


def inception_B(input):
    if K.image_dim_ordering() == "th":
        channel_axis = 1
    else:
        channel_axis = -1

    b1 = conv_block(input, 384, 1, 1)

    b2 = conv_block(input, 192, 1, 1)
    b2 = conv_block(b2, 224, 1, 7)
    b2 = conv_block(b2, 256, 7, 1)

    b3 = conv_block(input, 192, 1, 1)
    b3 = conv_block(b3, 192, 7, 1)
    b3 = conv_block(b3, 224, 1, 7)
    b3 = conv_block(b3, 224, 7, 1)
    b3 = conv_block(b3, 256, 1, 7)

    b4 = AveragePooling2D((3, 3), strides=(1, 1), border_mode='same')(input)
    b4 = conv_block(b4, 128, 1, 1)

    m = merge([b1, b2, b3, b4], mode='concat', concat_axis=channel_axis)
    return m


def inception_C(input):
    if K.image_dim_ordering() == "th":
        channel_axis = 1
    else:
        channel_axis = -1

    c1 = conv_block(input, 256, 1, 1)

    c2 = conv_block(input, 384, 1, 1)
    c2_1 = conv_block(c2, 256, 1, 3)
    c2_2 = conv_block(c2, 256, 3, 1)
    c2 = merge([c2_1, c2_2], mode='concat', concat_axis=channel_axis)

    c3 = conv_block(input, 384, 1, 1)
    c3 = conv_block(c3, 448, 3, 1)
    c3 = conv_block(c3, 512, 1, 3)
    c3_1 = conv_block(c3, 256, 1, 3)
    c3_2 = conv_block(c3, 256, 3, 1)
    c3 = merge([c3_1, c3_2], mode='concat', concat_axis=channel_axis)

    c4 = AveragePooling2D((3, 3), strides=(1, 1), border_mode='same')(input)
    c4 = conv_block(c4, 256, 1, 1)

    m = merge([c1, c2, c3, c4], mode='concat', concat_axis=channel_axis)
    return m


def reduction_A(input):
    if K.image_dim_ordering() == "th":
        channel_axis = 1
    else:
        channel_axis = -1

    r1 = conv_block(input, 384, 3, 3, subsample=(2, 2), border_mode='valid')

    r2 = conv_block(input, 192, 1, 1)
    r2 = conv_block(r2, 224, 3, 3)
    r2 = conv_block(r2, 256, 3, 3, subsample=(2, 2), border_mode='valid')

    r3 = MaxPooling2D((3, 3), strides=(2, 2), border_mode='valid')(input)

    m = merge([r1, r2, r3], mode='concat', concat_axis=channel_axis)
    return m


def reduction_B(input):
    if K.image_dim_ordering() == "th":
        channel_axis = 1
    else:
        channel_axis = -1

    r1 = conv_block(input, 192, 1, 1)
    r1 = conv_block(r1, 192, 3, 3, subsample=(2, 2), border_mode='valid')

    r2 = conv_block(input, 256, 1, 1)
    r2 = conv_block(r2, 256, 1, 7)
    r2 = conv_block(r2, 320, 7, 1)
    r2 = conv_block(r2, 320, 3, 3, subsample=(2, 2), border_mode='valid')

    r3 = MaxPooling2D((3, 3), strides=(2, 2), border_mode='valid')(input)

    m = merge([r1, r2, r3], mode='concat', concat_axis=channel_axis)
    return m


def create_inception_v4(nb_classes=1001, load_weights=True):
    '''
    Creates a inception v4 network
    :param nb_classes: number of classes.txt
    :return: Keras Model with 1 input and 1 output
    '''

    if K.image_dim_ordering() == 'th':
        init = Input((3, 299, 299))
    else:
        init = Input((299, 299, 3))

    # Input Shape is 299 x 299 x 3 (tf) or 3 x 299 x 299 (th)
    x = inception_stem(init)

    # 4 x Inception A
    for i in range(4):
        x = inception_A(x)

    # Reduction A
    x = reduction_A(x)

    # 7 x Inception B
    for i in range(7):
        x = inception_B(x)

    # Reduction B
    x = reduction_B(x)

    # 3 x Inception C
    for i in range(3):
        x = inception_C(x)

    # Average Pooling
    x = AveragePooling2D((8, 8))(x)

    # Dropout
    x = Dropout(0.8)(x)
    x = Flatten()(x)

    # Output
    out = Dense(output_dim=nb_classes, activation='softmax')(x)

    model = Model(init, out, name='Inception-v4')

    if load_weights:
        if K.backend() == "theano":
            if K.image_dim_ordering() == "th":
                weights = get_file('inception_v4_weights_th_dim_ordering_th_kernels.h5', TH_BACKEND_TH_DIM_ORDERING,
                                   cache_subdir='models')
            else:
                weights = get_file('inception_v4_weights_tf_dim_ordering_th_kernels.h5', TH_BACKEND_TF_DIM_ORDERING,
                                   cache_subdir='models')
        else:
            if K.image_dim_ordering() == "th":
                weights = get_file('inception_v4_weights_th_dim_ordering_tf_kernels.h5', TF_BACKEND_TH_DIM_ORDERING,
                                   cache_subdir='models')
            else:
                weights = get_file('inception_v4_weights_tf_dim_ordering_tf_kernels.h5', TF_BACKEND_TF_DIM_ORDERING,
                                   cache_subdir='models')

        model.load_weights("inception_v4_weights_tf_dim_ordering_tf_kernels.h5")
        print("Model weights loaded.")

    return model


# if __name__ == "__main__":
#     # from keras.utils.visualize_util import plot

#     inception_v4 = create_inception_v4(load_weights=True)
#     # inception_v4.summary()

#     # plot(inception_v4, to_file="Inception-v4.png", show_shapes=True)

# %%
inception_v4 = create_inception_v4(18,load_weights=False)

# %%
from keras.preprocessing import image
generator = image.ImageDataGenerator(horizontal_flip=True, rotation_range=10, shear_range=.1)
gen = generator.flow_from_directory("datasets/grocery/GroceryStoreDataset-master/dataset/train/Fruit/", target_size=(299, 299), batch_size=32)
# Out:
# Found 12733 images belonging to 18 classes.

# %%
inception_v4.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_3 (InputLayer)             (None, 299, 299, 3)   0
# ____________________________________________________________________________________________________
# convolution2d_299 (Convolution2D (None, 149, 149, 32)  864         input_3[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_299 (BatchNor (None, 149, 149, 32)  128         convolution2d_299[0][0]
# ____________________________________________________________________________________________________
# activation_299 (Activation)      (None, 149, 149, 32)  0           batchnormalization_299[0][0]
# ____________________________________________________________________________________________________
# convolution2d_300 (Convolution2D (None, 147, 147, 32)  9216        activation_299[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_300 (BatchNor (None, 147, 147, 32)  128         convolution2d_300[0][0]
# ____________________________________________________________________________________________________
# activation_300 (Activation)      (None, 147, 147, 32)  0           batchnormalization_300[0][0]
# ____________________________________________________________________________________________________
# convolution2d_301 (Convolution2D (None, 147, 147, 64)  18432       activation_300[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_301 (BatchNor (None, 147, 147, 64)  256         convolution2d_301[0][0]
# ____________________________________________________________________________________________________
# activation_301 (Activation)      (None, 147, 147, 64)  0           batchnormalization_301[0][0]
# ____________________________________________________________________________________________________
# convolution2d_302 (Convolution2D (None, 73, 73, 96)    55296       activation_301[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_302 (BatchNor (None, 73, 73, 96)    384         convolution2d_302[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_9 (MaxPooling2D)    (None, 73, 73, 64)    0           activation_301[0][0]
# ____________________________________________________________________________________________________
# activation_302 (Activation)      (None, 73, 73, 96)    0           batchnormalization_302[0][0]
# ____________________________________________________________________________________________________
# merge_51 (Merge)                 (None, 73, 73, 160)   0           maxpooling2d_9[0][0]
#                                                                    activation_302[0][0]
# ____________________________________________________________________________________________________
# convolution2d_305 (Convolution2D (None, 73, 73, 64)    10240       merge_51[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_305 (BatchNor (None, 73, 73, 64)    256         convolution2d_305[0][0]
# ____________________________________________________________________________________________________
# activation_305 (Activation)      (None, 73, 73, 64)    0           batchnormalization_305[0][0]
# ____________________________________________________________________________________________________
# convolution2d_306 (Convolution2D (None, 73, 73, 64)    28672       activation_305[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_306 (BatchNor (None, 73, 73, 64)    256         convolution2d_306[0][0]
# ____________________________________________________________________________________________________
# activation_306 (Activation)      (None, 73, 73, 64)    0           batchnormalization_306[0][0]
# ____________________________________________________________________________________________________
# convolution2d_303 (Convolution2D (None, 73, 73, 64)    10240       merge_51[0][0]
# ____________________________________________________________________________________________________
# convolution2d_307 (Convolution2D (None, 73, 73, 64)    28672       activation_306[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_303 (BatchNor (None, 73, 73, 64)    256         convolution2d_303[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_307 (BatchNor (None, 73, 73, 64)    256         convolution2d_307[0][0]
# ____________________________________________________________________________________________________
# activation_303 (Activation)      (None, 73, 73, 64)    0           batchnormalization_303[0][0]
# ____________________________________________________________________________________________________
# activation_307 (Activation)      (None, 73, 73, 64)    0           batchnormalization_307[0][0]
# ____________________________________________________________________________________________________
# convolution2d_304 (Convolution2D (None, 71, 71, 96)    55296       activation_303[0][0]
# ____________________________________________________________________________________________________
# convolution2d_308 (Convolution2D (None, 71, 71, 96)    55296       activation_307[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_304 (BatchNor (None, 71, 71, 96)    384         convolution2d_304[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_308 (BatchNor (None, 71, 71, 96)    384         convolution2d_308[0][0]
# ____________________________________________________________________________________________________
# activation_304 (Activation)      (None, 71, 71, 96)    0           batchnormalization_304[0][0]
# ____________________________________________________________________________________________________
# activation_308 (Activation)      (None, 71, 71, 96)    0           batchnormalization_308[0][0]
# ____________________________________________________________________________________________________
# merge_52 (Merge)                 (None, 71, 71, 192)   0           activation_304[0][0]
#                                                                    activation_308[0][0]
# ____________________________________________________________________________________________________
# convolution2d_309 (Convolution2D (None, 35, 35, 192)   331776      merge_52[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_309 (BatchNor (None, 35, 35, 192)   768         convolution2d_309[0][0]
# ____________________________________________________________________________________________________
# activation_309 (Activation)      (None, 35, 35, 192)   0           batchnormalization_309[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_10 (MaxPooling2D)   (None, 35, 35, 192)   0           merge_52[0][0]
# ____________________________________________________________________________________________________
# merge_53 (Merge)                 (None, 35, 35, 384)   0           activation_309[0][0]
#                                                                    maxpooling2d_10[0][0]
# ____________________________________________________________________________________________________
# convolution2d_313 (Convolution2D (None, 35, 35, 64)    24576       merge_53[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_313 (BatchNor (None, 35, 35, 64)    256         convolution2d_313[0][0]
# ____________________________________________________________________________________________________
# activation_313 (Activation)      (None, 35, 35, 64)    0           batchnormalization_313[0][0]
# ____________________________________________________________________________________________________
# convolution2d_311 (Convolution2D (None, 35, 35, 64)    24576       merge_53[0][0]
# ____________________________________________________________________________________________________
# convolution2d_314 (Convolution2D (None, 35, 35, 96)    55296       activation_313[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_311 (BatchNor (None, 35, 35, 64)    256         convolution2d_311[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_314 (BatchNor (None, 35, 35, 96)    384         convolution2d_314[0][0]
# ____________________________________________________________________________________________________
# activation_311 (Activation)      (None, 35, 35, 64)    0           batchnormalization_311[0][0]
# ____________________________________________________________________________________________________
# activation_314 (Activation)      (None, 35, 35, 96)    0           batchnormalization_314[0][0]
# ____________________________________________________________________________________________________
# averagepooling2d_31 (AveragePool (None, 35, 35, 384)   0           merge_53[0][0]
# ____________________________________________________________________________________________________
# convolution2d_310 (Convolution2D (None, 35, 35, 96)    36864       merge_53[0][0]
# ____________________________________________________________________________________________________
# convolution2d_312 (Convolution2D (None, 35, 35, 96)    55296       activation_311[0][0]
# ____________________________________________________________________________________________________
# convolution2d_315 (Convolution2D (None, 35, 35, 96)    82944       activation_314[0][0]
# ____________________________________________________________________________________________________
# convolution2d_316 (Convolution2D (None, 35, 35, 96)    36864       averagepooling2d_31[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_310 (BatchNor (None, 35, 35, 96)    384         convolution2d_310[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_312 (BatchNor (None, 35, 35, 96)    384         convolution2d_312[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_315 (BatchNor (None, 35, 35, 96)    384         convolution2d_315[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_316 (BatchNor (None, 35, 35, 96)    384         convolution2d_316[0][0]
# ____________________________________________________________________________________________________
# activation_310 (Activation)      (None, 35, 35, 96)    0           batchnormalization_310[0][0]
# ____________________________________________________________________________________________________
# activation_312 (Activation)      (None, 35, 35, 96)    0           batchnormalization_312[0][0]
# ____________________________________________________________________________________________________
# activation_315 (Activation)      (None, 35, 35, 96)    0           batchnormalization_315[0][0]
# ____________________________________________________________________________________________________
# activation_316 (Activation)      (None, 35, 35, 96)    0           batchnormalization_316[0][0]
# ____________________________________________________________________________________________________
# merge_54 (Merge)                 (None, 35, 35, 384)   0           activation_310[0][0]
#                                                                    activation_312[0][0]
#                                                                    activation_315[0][0]
#                                                                    activation_316[0][0]
# ____________________________________________________________________________________________________
# convolution2d_320 (Convolution2D (None, 35, 35, 64)    24576       merge_54[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_320 (BatchNor (None, 35, 35, 64)    256         convolution2d_320[0][0]
# ____________________________________________________________________________________________________
# activation_320 (Activation)      (None, 35, 35, 64)    0           batchnormalization_320[0][0]
# ____________________________________________________________________________________________________
# convolution2d_318 (Convolution2D (None, 35, 35, 64)    24576       merge_54[0][0]
# ____________________________________________________________________________________________________
# convolution2d_321 (Convolution2D (None, 35, 35, 96)    55296       activation_320[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_318 (BatchNor (None, 35, 35, 64)    256         convolution2d_318[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_321 (BatchNor (None, 35, 35, 96)    384         convolution2d_321[0][0]
# ____________________________________________________________________________________________________
# activation_318 (Activation)      (None, 35, 35, 64)    0           batchnormalization_318[0][0]
# ____________________________________________________________________________________________________
# activation_321 (Activation)      (None, 35, 35, 96)    0           batchnormalization_321[0][0]
# ____________________________________________________________________________________________________
# averagepooling2d_32 (AveragePool (None, 35, 35, 384)   0           merge_54[0][0]
# ____________________________________________________________________________________________________
# convolution2d_317 (Convolution2D (None, 35, 35, 96)    36864       merge_54[0][0]
# ____________________________________________________________________________________________________
# convolution2d_319 (Convolution2D (None, 35, 35, 96)    55296       activation_318[0][0]
# ____________________________________________________________________________________________________
# convolution2d_322 (Convolution2D (None, 35, 35, 96)    82944       activation_321[0][0]
# ____________________________________________________________________________________________________
# convolution2d_323 (Convolution2D (None, 35, 35, 96)    36864       averagepooling2d_32[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_317 (BatchNor (None, 35, 35, 96)    384         convolution2d_317[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_319 (BatchNor (None, 35, 35, 96)    384         convolution2d_319[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_322 (BatchNor (None, 35, 35, 96)    384         convolution2d_322[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_323 (BatchNor (None, 35, 35, 96)    384         convolution2d_323[0][0]
# ____________________________________________________________________________________________________
# activation_317 (Activation)      (None, 35, 35, 96)    0           batchnormalization_317[0][0]
# ____________________________________________________________________________________________________
# activation_319 (Activation)      (None, 35, 35, 96)    0           batchnormalization_319[0][0]
# ____________________________________________________________________________________________________
# activation_322 (Activation)      (None, 35, 35, 96)    0           batchnormalization_322[0][0]
# ____________________________________________________________________________________________________
# activation_323 (Activation)      (None, 35, 35, 96)    0           batchnormalization_323[0][0]
# ____________________________________________________________________________________________________
# merge_55 (Merge)                 (None, 35, 35, 384)   0           activation_317[0][0]
#                                                                    activation_319[0][0]
#                                                                    activation_322[0][0]
#                                                                    activation_323[0][0]
# ____________________________________________________________________________________________________
# convolution2d_327 (Convolution2D (None, 35, 35, 64)    24576       merge_55[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_327 (BatchNor (None, 35, 35, 64)    256         convolution2d_327[0][0]
# ____________________________________________________________________________________________________
# activation_327 (Activation)      (None, 35, 35, 64)    0           batchnormalization_327[0][0]
# ____________________________________________________________________________________________________
# convolution2d_325 (Convolution2D (None, 35, 35, 64)    24576       merge_55[0][0]
# ____________________________________________________________________________________________________
# convolution2d_328 (Convolution2D (None, 35, 35, 96)    55296       activation_327[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_325 (BatchNor (None, 35, 35, 64)    256         convolution2d_325[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_328 (BatchNor (None, 35, 35, 96)    384         convolution2d_328[0][0]
# ____________________________________________________________________________________________________
# activation_325 (Activation)      (None, 35, 35, 64)    0           batchnormalization_325[0][0]
# ____________________________________________________________________________________________________
# activation_328 (Activation)      (None, 35, 35, 96)    0           batchnormalization_328[0][0]
# ____________________________________________________________________________________________________
# averagepooling2d_33 (AveragePool (None, 35, 35, 384)   0           merge_55[0][0]
# ____________________________________________________________________________________________________
# convolution2d_324 (Convolution2D (None, 35, 35, 96)    36864       merge_55[0][0]
# ____________________________________________________________________________________________________
# convolution2d_326 (Convolution2D (None, 35, 35, 96)    55296       activation_325[0][0]
# ____________________________________________________________________________________________________
# convolution2d_329 (Convolution2D (None, 35, 35, 96)    82944       activation_328[0][0]
# ____________________________________________________________________________________________________
# convolution2d_330 (Convolution2D (None, 35, 35, 96)    36864       averagepooling2d_33[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_324 (BatchNor (None, 35, 35, 96)    384         convolution2d_324[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_326 (BatchNor (None, 35, 35, 96)    384         convolution2d_326[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_329 (BatchNor (None, 35, 35, 96)    384         convolution2d_329[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_330 (BatchNor (None, 35, 35, 96)    384         convolution2d_330[0][0]
# ____________________________________________________________________________________________________
# activation_324 (Activation)      (None, 35, 35, 96)    0           batchnormalization_324[0][0]
# ____________________________________________________________________________________________________
# activation_326 (Activation)      (None, 35, 35, 96)    0           batchnormalization_326[0][0]
# ____________________________________________________________________________________________________
# activation_329 (Activation)      (None, 35, 35, 96)    0           batchnormalization_329[0][0]
# ____________________________________________________________________________________________________
# activation_330 (Activation)      (None, 35, 35, 96)    0           batchnormalization_330[0][0]
# ____________________________________________________________________________________________________
# merge_56 (Merge)                 (None, 35, 35, 384)   0           activation_324[0][0]
#                                                                    activation_326[0][0]
#                                                                    activation_329[0][0]
#                                                                    activation_330[0][0]
# ____________________________________________________________________________________________________
# convolution2d_334 (Convolution2D (None, 35, 35, 64)    24576       merge_56[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_334 (BatchNor (None, 35, 35, 64)    256         convolution2d_334[0][0]
# ____________________________________________________________________________________________________
# activation_334 (Activation)      (None, 35, 35, 64)    0           batchnormalization_334[0][0]
# ____________________________________________________________________________________________________
# convolution2d_332 (Convolution2D (None, 35, 35, 64)    24576       merge_56[0][0]
# ____________________________________________________________________________________________________
# convolution2d_335 (Convolution2D (None, 35, 35, 96)    55296       activation_334[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_332 (BatchNor (None, 35, 35, 64)    256         convolution2d_332[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_335 (BatchNor (None, 35, 35, 96)    384         convolution2d_335[0][0]
# ____________________________________________________________________________________________________
# activation_332 (Activation)      (None, 35, 35, 64)    0           batchnormalization_332[0][0]
# ____________________________________________________________________________________________________
# activation_335 (Activation)      (None, 35, 35, 96)    0           batchnormalization_335[0][0]
# ____________________________________________________________________________________________________
# averagepooling2d_34 (AveragePool (None, 35, 35, 384)   0           merge_56[0][0]
# ____________________________________________________________________________________________________
# convolution2d_331 (Convolution2D (None, 35, 35, 96)    36864       merge_56[0][0]
# ____________________________________________________________________________________________________
# convolution2d_333 (Convolution2D (None, 35, 35, 96)    55296       activation_332[0][0]
# ____________________________________________________________________________________________________
# convolution2d_336 (Convolution2D (None, 35, 35, 96)    82944       activation_335[0][0]
# ____________________________________________________________________________________________________
# convolution2d_337 (Convolution2D (None, 35, 35, 96)    36864       averagepooling2d_34[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_331 (BatchNor (None, 35, 35, 96)    384         convolution2d_331[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_333 (BatchNor (None, 35, 35, 96)    384         convolution2d_333[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_336 (BatchNor (None, 35, 35, 96)    384         convolution2d_336[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_337 (BatchNor (None, 35, 35, 96)    384         convolution2d_337[0][0]
# ____________________________________________________________________________________________________
# activation_331 (Activation)      (None, 35, 35, 96)    0           batchnormalization_331[0][0]
# ____________________________________________________________________________________________________
# activation_333 (Activation)      (None, 35, 35, 96)    0           batchnormalization_333[0][0]
# ____________________________________________________________________________________________________
# activation_336 (Activation)      (None, 35, 35, 96)    0           batchnormalization_336[0][0]
# ____________________________________________________________________________________________________
# activation_337 (Activation)      (None, 35, 35, 96)    0           batchnormalization_337[0][0]
# ____________________________________________________________________________________________________
# merge_57 (Merge)                 (None, 35, 35, 384)   0           activation_331[0][0]
#                                                                    activation_333[0][0]
#                                                                    activation_336[0][0]
#                                                                    activation_337[0][0]
# ____________________________________________________________________________________________________
# convolution2d_339 (Convolution2D (None, 35, 35, 192)   73728       merge_57[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_339 (BatchNor (None, 35, 35, 192)   768         convolution2d_339[0][0]
# ____________________________________________________________________________________________________
# activation_339 (Activation)      (None, 35, 35, 192)   0           batchnormalization_339[0][0]
# ____________________________________________________________________________________________________
# convolution2d_340 (Convolution2D (None, 35, 35, 224)   387072      activation_339[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_340 (BatchNor (None, 35, 35, 224)   896         convolution2d_340[0][0]
# ____________________________________________________________________________________________________
# activation_340 (Activation)      (None, 35, 35, 224)   0           batchnormalization_340[0][0]
# ____________________________________________________________________________________________________
# convolution2d_338 (Convolution2D (None, 17, 17, 384)   1327104     merge_57[0][0]
# ____________________________________________________________________________________________________
# convolution2d_341 (Convolution2D (None, 17, 17, 256)   516096      activation_340[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_338 (BatchNor (None, 17, 17, 384)   1536        convolution2d_338[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_341 (BatchNor (None, 17, 17, 256)   1024        convolution2d_341[0][0]
# ____________________________________________________________________________________________________
# activation_338 (Activation)      (None, 17, 17, 384)   0           batchnormalization_338[0][0]
# ____________________________________________________________________________________________________
# activation_341 (Activation)      (None, 17, 17, 256)   0           batchnormalization_341[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_11 (MaxPooling2D)   (None, 17, 17, 384)   0           merge_57[0][0]
# ____________________________________________________________________________________________________
# merge_58 (Merge)                 (None, 17, 17, 1024)  0           activation_338[0][0]
#                                                                    activation_341[0][0]
#                                                                    maxpooling2d_11[0][0]
# ____________________________________________________________________________________________________
# convolution2d_346 (Convolution2D (None, 17, 17, 192)   196608      merge_58[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_346 (BatchNor (None, 17, 17, 192)   768         convolution2d_346[0][0]
# ____________________________________________________________________________________________________
# activation_346 (Activation)      (None, 17, 17, 192)   0           batchnormalization_346[0][0]
# ____________________________________________________________________________________________________
# convolution2d_347 (Convolution2D (None, 17, 17, 192)   258048      activation_346[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_347 (BatchNor (None, 17, 17, 192)   768         convolution2d_347[0][0]
# ____________________________________________________________________________________________________
# activation_347 (Activation)      (None, 17, 17, 192)   0           batchnormalization_347[0][0]
# ____________________________________________________________________________________________________
# convolution2d_343 (Convolution2D (None, 17, 17, 192)   196608      merge_58[0][0]
# ____________________________________________________________________________________________________
# convolution2d_348 (Convolution2D (None, 17, 17, 224)   301056      activation_347[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_343 (BatchNor (None, 17, 17, 192)   768         convolution2d_343[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_348 (BatchNor (None, 17, 17, 224)   896         convolution2d_348[0][0]
# ____________________________________________________________________________________________________
# activation_343 (Activation)      (None, 17, 17, 192)   0           batchnormalization_343[0][0]
# ____________________________________________________________________________________________________
# activation_348 (Activation)      (None, 17, 17, 224)   0           batchnormalization_348[0][0]
# ____________________________________________________________________________________________________
# convolution2d_344 (Convolution2D (None, 17, 17, 224)   301056      activation_343[0][0]
# ____________________________________________________________________________________________________
# convolution2d_349 (Convolution2D (None, 17, 17, 224)   351232      activation_348[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_344 (BatchNor (None, 17, 17, 224)   896         convolution2d_344[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_349 (BatchNor (None, 17, 17, 224)   896         convolution2d_349[0][0]
# ____________________________________________________________________________________________________
# activation_344 (Activation)      (None, 17, 17, 224)   0           batchnormalization_344[0][0]
# ____________________________________________________________________________________________________
# activation_349 (Activation)      (None, 17, 17, 224)   0           batchnormalization_349[0][0]
# ____________________________________________________________________________________________________
# averagepooling2d_35 (AveragePool (None, 17, 17, 1024)  0           merge_58[0][0]
# ____________________________________________________________________________________________________
# convolution2d_342 (Convolution2D (None, 17, 17, 384)   393216      merge_58[0][0]
# ____________________________________________________________________________________________________
# convolution2d_345 (Convolution2D (None, 17, 17, 256)   401408      activation_344[0][0]
# ____________________________________________________________________________________________________
# convolution2d_350 (Convolution2D (None, 17, 17, 256)   401408      activation_349[0][0]
# ____________________________________________________________________________________________________
# convolution2d_351 (Convolution2D (None, 17, 17, 128)   131072      averagepooling2d_35[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_342 (BatchNor (None, 17, 17, 384)   1536        convolution2d_342[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_345 (BatchNor (None, 17, 17, 256)   1024        convolution2d_345[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_350 (BatchNor (None, 17, 17, 256)   1024        convolution2d_350[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_351 (BatchNor (None, 17, 17, 128)   512         convolution2d_351[0][0]
# ____________________________________________________________________________________________________
# activation_342 (Activation)      (None, 17, 17, 384)   0           batchnormalization_342[0][0]
# ____________________________________________________________________________________________________
# activation_345 (Activation)      (None, 17, 17, 256)   0           batchnormalization_345[0][0]
# ____________________________________________________________________________________________________
# activation_350 (Activation)      (None, 17, 17, 256)   0           batchnormalization_350[0][0]
# ____________________________________________________________________________________________________
# activation_351 (Activation)      (None, 17, 17, 128)   0           batchnormalization_351[0][0]
# ____________________________________________________________________________________________________
# merge_59 (Merge)                 (None, 17, 17, 1024)  0           activation_342[0][0]
#                                                                    activation_345[0][0]
#                                                                    activation_350[0][0]
#                                                                    activation_351[0][0]
# ____________________________________________________________________________________________________
# convolution2d_356 (Convolution2D (None, 17, 17, 192)   196608      merge_59[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_356 (BatchNor (None, 17, 17, 192)   768         convolution2d_356[0][0]
# ____________________________________________________________________________________________________
# activation_356 (Activation)      (None, 17, 17, 192)   0           batchnormalization_356[0][0]
# ____________________________________________________________________________________________________
# convolution2d_357 (Convolution2D (None, 17, 17, 192)   258048      activation_356[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_357 (BatchNor (None, 17, 17, 192)   768         convolution2d_357[0][0]
# ____________________________________________________________________________________________________
# activation_357 (Activation)      (None, 17, 17, 192)   0           batchnormalization_357[0][0]
# ____________________________________________________________________________________________________
# convolution2d_353 (Convolution2D (None, 17, 17, 192)   196608      merge_59[0][0]
# ____________________________________________________________________________________________________
# convolution2d_358 (Convolution2D (None, 17, 17, 224)   301056      activation_357[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_353 (BatchNor (None, 17, 17, 192)   768         convolution2d_353[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_358 (BatchNor (None, 17, 17, 224)   896         convolution2d_358[0][0]
# ____________________________________________________________________________________________________
# activation_353 (Activation)      (None, 17, 17, 192)   0           batchnormalization_353[0][0]
# ____________________________________________________________________________________________________
# activation_358 (Activation)      (None, 17, 17, 224)   0           batchnormalization_358[0][0]
# ____________________________________________________________________________________________________
# convolution2d_354 (Convolution2D (None, 17, 17, 224)   301056      activation_353[0][0]
# ____________________________________________________________________________________________________
# convolution2d_359 (Convolution2D (None, 17, 17, 224)   351232      activation_358[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_354 (BatchNor (None, 17, 17, 224)   896         convolution2d_354[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_359 (BatchNor (None, 17, 17, 224)   896         convolution2d_359[0][0]
# ____________________________________________________________________________________________________
# activation_354 (Activation)      (None, 17, 17, 224)   0           batchnormalization_354[0][0]
# ____________________________________________________________________________________________________
# activation_359 (Activation)      (None, 17, 17, 224)   0           batchnormalization_359[0][0]
# ____________________________________________________________________________________________________
# averagepooling2d_36 (AveragePool (None, 17, 17, 1024)  0           merge_59[0][0]
# ____________________________________________________________________________________________________
# convolution2d_352 (Convolution2D (None, 17, 17, 384)   393216      merge_59[0][0]
# ____________________________________________________________________________________________________
# convolution2d_355 (Convolution2D (None, 17, 17, 256)   401408      activation_354[0][0]
# ____________________________________________________________________________________________________
# convolution2d_360 (Convolution2D (None, 17, 17, 256)   401408      activation_359[0][0]
# ____________________________________________________________________________________________________
# convolution2d_361 (Convolution2D (None, 17, 17, 128)   131072      averagepooling2d_36[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_352 (BatchNor (None, 17, 17, 384)   1536        convolution2d_352[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_355 (BatchNor (None, 17, 17, 256)   1024        convolution2d_355[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_360 (BatchNor (None, 17, 17, 256)   1024        convolution2d_360[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_361 (BatchNor (None, 17, 17, 128)   512         convolution2d_361[0][0]
# ____________________________________________________________________________________________________
# activation_352 (Activation)      (None, 17, 17, 384)   0           batchnormalization_352[0][0]
# ____________________________________________________________________________________________________
# activation_355 (Activation)      (None, 17, 17, 256)   0           batchnormalization_355[0][0]
# ____________________________________________________________________________________________________
# activation_360 (Activation)      (None, 17, 17, 256)   0           batchnormalization_360[0][0]
# ____________________________________________________________________________________________________
# activation_361 (Activation)      (None, 17, 17, 128)   0           batchnormalization_361[0][0]
# ____________________________________________________________________________________________________
# merge_60 (Merge)                 (None, 17, 17, 1024)  0           activation_352[0][0]
#                                                                    activation_355[0][0]
#                                                                    activation_360[0][0]
#                                                                    activation_361[0][0]
# ____________________________________________________________________________________________________
# convolution2d_366 (Convolution2D (None, 17, 17, 192)   196608      merge_60[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_366 (BatchNor (None, 17, 17, 192)   768         convolution2d_366[0][0]
# ____________________________________________________________________________________________________
# activation_366 (Activation)      (None, 17, 17, 192)   0           batchnormalization_366[0][0]
# ____________________________________________________________________________________________________
# convolution2d_367 (Convolution2D (None, 17, 17, 192)   258048      activation_366[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_367 (BatchNor (None, 17, 17, 192)   768         convolution2d_367[0][0]
# ____________________________________________________________________________________________________
# activation_367 (Activation)      (None, 17, 17, 192)   0           batchnormalization_367[0][0]
# ____________________________________________________________________________________________________
# convolution2d_363 (Convolution2D (None, 17, 17, 192)   196608      merge_60[0][0]
# ____________________________________________________________________________________________________
# convolution2d_368 (Convolution2D (None, 17, 17, 224)   301056      activation_367[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_363 (BatchNor (None, 17, 17, 192)   768         convolution2d_363[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_368 (BatchNor (None, 17, 17, 224)   896         convolution2d_368[0][0]
# ____________________________________________________________________________________________________
# activation_363 (Activation)      (None, 17, 17, 192)   0           batchnormalization_363[0][0]
# ____________________________________________________________________________________________________
# activation_368 (Activation)      (None, 17, 17, 224)   0           batchnormalization_368[0][0]
# ____________________________________________________________________________________________________
# convolution2d_364 (Convolution2D (None, 17, 17, 224)   301056      activation_363[0][0]
# ____________________________________________________________________________________________________
# convolution2d_369 (Convolution2D (None, 17, 17, 224)   351232      activation_368[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_364 (BatchNor (None, 17, 17, 224)   896         convolution2d_364[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_369 (BatchNor (None, 17, 17, 224)   896         convolution2d_369[0][0]
# ...
#                                                                    activation_427[0][0]
# ____________________________________________________________________________________________________
# convolution2d_432 (Convolution2D (None, 8, 8, 384)     589824      merge_69[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_432 (BatchNor (None, 8, 8, 384)     1536        convolution2d_432[0][0]
# ____________________________________________________________________________________________________
# activation_432 (Activation)      (None, 8, 8, 384)     0           batchnormalization_432[0][0]
# ____________________________________________________________________________________________________
# convolution2d_433 (Convolution2D (None, 8, 8, 448)     516096      activation_432[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_433 (BatchNor (None, 8, 8, 448)     1792        convolution2d_433[0][0]
# ____________________________________________________________________________________________________
# activation_433 (Activation)      (None, 8, 8, 448)     0           batchnormalization_433[0][0]
# ____________________________________________________________________________________________________
# convolution2d_429 (Convolution2D (None, 8, 8, 384)     589824      merge_69[0][0]
# ____________________________________________________________________________________________________
# convolution2d_434 (Convolution2D (None, 8, 8, 512)     688128      activation_433[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_429 (BatchNor (None, 8, 8, 384)     1536        convolution2d_429[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_434 (BatchNor (None, 8, 8, 512)     2048        convolution2d_434[0][0]
# ____________________________________________________________________________________________________
# activation_429 (Activation)      (None, 8, 8, 384)     0           batchnormalization_429[0][0]
# ____________________________________________________________________________________________________
# activation_434 (Activation)      (None, 8, 8, 512)     0           batchnormalization_434[0][0]
# ____________________________________________________________________________________________________
# convolution2d_430 (Convolution2D (None, 8, 8, 256)     294912      activation_429[0][0]
# ____________________________________________________________________________________________________
# convolution2d_431 (Convolution2D (None, 8, 8, 256)     294912      activation_429[0][0]
# ____________________________________________________________________________________________________
# convolution2d_435 (Convolution2D (None, 8, 8, 256)     393216      activation_434[0][0]
# ____________________________________________________________________________________________________
# convolution2d_436 (Convolution2D (None, 8, 8, 256)     393216      activation_434[0][0]
# ____________________________________________________________________________________________________
# averagepooling2d_43 (AveragePool (None, 8, 8, 1536)    0           merge_69[0][0]
# ____________________________________________________________________________________________________
# convolution2d_428 (Convolution2D (None, 8, 8, 256)     393216      merge_69[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_430 (BatchNor (None, 8, 8, 256)     1024        convolution2d_430[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_431 (BatchNor (None, 8, 8, 256)     1024        convolution2d_431[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_435 (BatchNor (None, 8, 8, 256)     1024        convolution2d_435[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_436 (BatchNor (None, 8, 8, 256)     1024        convolution2d_436[0][0]
# ____________________________________________________________________________________________________
# convolution2d_437 (Convolution2D (None, 8, 8, 256)     393216      averagepooling2d_43[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_428 (BatchNor (None, 8, 8, 256)     1024        convolution2d_428[0][0]
# ____________________________________________________________________________________________________
# activation_430 (Activation)      (None, 8, 8, 256)     0           batchnormalization_430[0][0]
# ____________________________________________________________________________________________________
# activation_431 (Activation)      (None, 8, 8, 256)     0           batchnormalization_431[0][0]
# ____________________________________________________________________________________________________
# activation_435 (Activation)      (None, 8, 8, 256)     0           batchnormalization_435[0][0]
# ____________________________________________________________________________________________________
# activation_436 (Activation)      (None, 8, 8, 256)     0           batchnormalization_436[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_437 (BatchNor (None, 8, 8, 256)     1024        convolution2d_437[0][0]
# ____________________________________________________________________________________________________
# activation_428 (Activation)      (None, 8, 8, 256)     0           batchnormalization_428[0][0]
# ____________________________________________________________________________________________________
# merge_70 (Merge)                 (None, 8, 8, 512)     0           activation_430[0][0]
#                                                                    activation_431[0][0]
# ____________________________________________________________________________________________________
# merge_71 (Merge)                 (None, 8, 8, 512)     0           activation_435[0][0]
#                                                                    activation_436[0][0]
# ____________________________________________________________________________________________________
# activation_437 (Activation)      (None, 8, 8, 256)     0           batchnormalization_437[0][0]
# ____________________________________________________________________________________________________
# merge_72 (Merge)                 (None, 8, 8, 1536)    0           activation_428[0][0]
#                                                                    merge_70[0][0]
#                                                                    merge_71[0][0]
#                                                                    activation_437[0][0]
# ____________________________________________________________________________________________________
# convolution2d_442 (Convolution2D (None, 8, 8, 384)     589824      merge_72[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_442 (BatchNor (None, 8, 8, 384)     1536        convolution2d_442[0][0]
# ____________________________________________________________________________________________________
# activation_442 (Activation)      (None, 8, 8, 384)     0           batchnormalization_442[0][0]
# ____________________________________________________________________________________________________
# convolution2d_443 (Convolution2D (None, 8, 8, 448)     516096      activation_442[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_443 (BatchNor (None, 8, 8, 448)     1792        convolution2d_443[0][0]
# ____________________________________________________________________________________________________
# activation_443 (Activation)      (None, 8, 8, 448)     0           batchnormalization_443[0][0]
# ____________________________________________________________________________________________________
# convolution2d_439 (Convolution2D (None, 8, 8, 384)     589824      merge_72[0][0]
# ____________________________________________________________________________________________________
# convolution2d_444 (Convolution2D (None, 8, 8, 512)     688128      activation_443[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_439 (BatchNor (None, 8, 8, 384)     1536        convolution2d_439[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_444 (BatchNor (None, 8, 8, 512)     2048        convolution2d_444[0][0]
# ____________________________________________________________________________________________________
# activation_439 (Activation)      (None, 8, 8, 384)     0           batchnormalization_439[0][0]
# ____________________________________________________________________________________________________
# activation_444 (Activation)      (None, 8, 8, 512)     0           batchnormalization_444[0][0]
# ____________________________________________________________________________________________________
# convolution2d_440 (Convolution2D (None, 8, 8, 256)     294912      activation_439[0][0]
# ____________________________________________________________________________________________________
# convolution2d_441 (Convolution2D (None, 8, 8, 256)     294912      activation_439[0][0]
# ____________________________________________________________________________________________________
# convolution2d_445 (Convolution2D (None, 8, 8, 256)     393216      activation_444[0][0]
# ____________________________________________________________________________________________________
# convolution2d_446 (Convolution2D (None, 8, 8, 256)     393216      activation_444[0][0]
# ____________________________________________________________________________________________________
# averagepooling2d_44 (AveragePool (None, 8, 8, 1536)    0           merge_72[0][0]
# ____________________________________________________________________________________________________
# convolution2d_438 (Convolution2D (None, 8, 8, 256)     393216      merge_72[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_440 (BatchNor (None, 8, 8, 256)     1024        convolution2d_440[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_441 (BatchNor (None, 8, 8, 256)     1024        convolution2d_441[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_445 (BatchNor (None, 8, 8, 256)     1024        convolution2d_445[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_446 (BatchNor (None, 8, 8, 256)     1024        convolution2d_446[0][0]
# ____________________________________________________________________________________________________
# convolution2d_447 (Convolution2D (None, 8, 8, 256)     393216      averagepooling2d_44[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_438 (BatchNor (None, 8, 8, 256)     1024        convolution2d_438[0][0]
# ____________________________________________________________________________________________________
# activation_440 (Activation)      (None, 8, 8, 256)     0           batchnormalization_440[0][0]
# ____________________________________________________________________________________________________
# activation_441 (Activation)      (None, 8, 8, 256)     0           batchnormalization_441[0][0]
# ____________________________________________________________________________________________________
# activation_445 (Activation)      (None, 8, 8, 256)     0           batchnormalization_445[0][0]
# ____________________________________________________________________________________________________
# activation_446 (Activation)      (None, 8, 8, 256)     0           batchnormalization_446[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_447 (BatchNor (None, 8, 8, 256)     1024        convolution2d_447[0][0]
# ____________________________________________________________________________________________________
# activation_438 (Activation)      (None, 8, 8, 256)     0           batchnormalization_438[0][0]
# ____________________________________________________________________________________________________
# merge_73 (Merge)                 (None, 8, 8, 512)     0           activation_440[0][0]
#                                                                    activation_441[0][0]
# ____________________________________________________________________________________________________
# merge_74 (Merge)                 (None, 8, 8, 512)     0           activation_445[0][0]
#                                                                    activation_446[0][0]
# ____________________________________________________________________________________________________
# activation_447 (Activation)      (None, 8, 8, 256)     0           batchnormalization_447[0][0]
# ____________________________________________________________________________________________________
# merge_75 (Merge)                 (None, 8, 8, 1536)    0           activation_438[0][0]
#                                                                    merge_73[0][0]
#                                                                    merge_74[0][0]
#                                                                    activation_447[0][0]
# ____________________________________________________________________________________________________
# averagepooling2d_45 (AveragePool (None, 1, 1, 1536)    0           merge_75[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 1, 1, 1536)    0           averagepooling2d_45[0][0]
# ____________________________________________________________________________________________________
# flatten_3 (Flatten)              (None, 1536)          0           dropout_3[0][0]
# ____________________________________________________________________________________________________
# dense_3 (Dense)                  (None, 18)            27666       flatten_3[0][0]
# ====================================================================================================
# Total params: 41,233,650
# Trainable params: 41,170,482
# Non-trainable params: 63,168
# ____________________________________________________________________________________________________

# %%
inception_v4.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
# Out:
# WARNING:tensorflow:From c:\users\administrator\appdata\local\programs\python\python36\lib\site-packages\keras\backend\tensorflow_backend.py:2385: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
inception_v4.fit_generator(gen,nb_epoch=10,samples_per_epoch=900)
# Out:
# Epoch 1/10
